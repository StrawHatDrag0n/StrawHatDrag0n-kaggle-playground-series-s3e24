# %%
import os
import numpy as np
from pathlib import Path
import pandas as pd
import optuna
import xgboost as xgb
from functools import partial
import lightgbm as lgbm
import catboost as cb
from joblib import Parallel, delayed
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import make_pipeline, make_union, FeatureUnion, Pipeline
from sklearn.preprocessing import   StandardScaler,RobustScaler, OneHotEncoder, FunctionTransformer, PowerTransformer, QuantileTransformer, \
                                    PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, RFE, RFECV, SelectFromModel
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# %%
class Config:
    CONTEST_TAG = 'playground-series-s3e24'
    ROOT_DIR = '../'
    FILE_NAME = 'lgbm-gbdt-v1'
    
    def __init__(self):
        self.iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
        self.seed = 42
        self.n_jobs = 8
        self.splits = 5
        self.target_col = 'smoking'
        self.index_col = 'id'
        self.optuna_trials = 30
        if self.iskaggle:
            self.train_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/train.csv')
            self.test_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/test.csv')
            self.Categoricalubmission_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/sample_submission.csv')
        else:
            self.train_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/train.csv')
            self.test_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/test.csv')
            self.submission_path = Path(f'{self.ROOT_DIR}/input/{self.CONTEST_TAG}/sample_submission.csv')

        self.default_rf_params =  {   
            'criterion': 'gini',
            'n_jobs': self.n_jobs, 
            'random_state': self.seed
        }
        self.default_cb_params =  {   
            'random_state': self.seed,
            'eval_metric': 'AUC',
            'loss_function': 'Logloss',
            'verbose': False
        }
        self.default_lgbm_gbdt_params = {
            'n_estimators': 10000,
            'random_state': self.seed,
            'n_jobs': self.n_jobs,
            'objective': 'binary',
            'verbose': -1,
            'boosting_type': 'gbdt',
            'bagging_freq': 1
        }

CFG = Config()
CLF = lgbm.LGBMClassifier

default_params = CFG.default_lgbm_gbdt_params

# %%
train_df = pd.read_csv(CFG.train_path, index_col=CFG.index_col)
test_df = pd.read_csv(CFG.test_path, index_col=CFG.index_col)

# %%
cat_cols = ['Urine protein', 'hearing(left)', 'hearing(right)', 'dental caries']
num_cols = ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
       'eyesight(right)', 'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
       'HDL', 'LDL', 'hemoglobin', 'serum creatinine', 'AST', 'ALT', 'Gtp', ]

# %%
X_train  = train_df.drop(CFG.target_col, axis=1)
y_train  = train_df[CFG.target_col]

X_test = test_df

# %%
def convert_to_categorial(X):
    new_X = X.copy()
    for col in X.columns:
        new_X[col] = pd.Categorical(X[col])
    return new_X


transformers = [
    ('robust', RobustScaler()),
    ('log', FunctionTransformer(func=np.log1p, feature_names_out=lambda x, features: [f'log_{feature}' for feature in features])), 
    ('power', PowerTransformer()), 
    ('quant', QuantileTransformer()), 
    ('poly', PolynomialFeatures())
]

numerical_transformer = Pipeline(steps=[
       ('feature_union', FeatureUnion(transformer_list=transformers))
])

# categorical_transformer = Pipeline(steps=[
#     ('1hot_encoder', OneHotEncoder())
# ])

categorical_transformer = Pipeline(steps=[
    ('pd_categorical', FunctionTransformer(func=convert_to_categorial))
])

preprocessor  = ColumnTransformer([
    ('cat', categorical_transformer, cat_cols),
    ('num', numerical_transformer, num_cols)
], n_jobs=-1)


feature_selection = Pipeline(steps=[
    ('select_from_model', SelectFromModel(CLF(**default_params)))
])

clf = Pipeline(steps = [
    ('rf', CLF(**default_params))
])

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('feature_selection', feature_selection),
#     ('classifier', clf)
])


# Tranform Data
X_train = pipeline.fit_transform(X_train, y_train)
X_test = pipeline.transform(X_test)

# %%
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')

# %%
def objective(trial: optuna.Trial, X, y):
    optuna_params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=20),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
        "max_bin": trial.suggest_int("max_bin", 200, 300),
        "lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
        "lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "bagging_fraction": trial.suggest_float(
            "bagging_fraction", 0.2, 0.95, step=0.1
        ),
        "feature_fraction": trial.suggest_float(
            "feature_fraction", 0.2, 0.95, step=0.1
        ),
    }
    params = {**default_params, **optuna_params}
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1121218)
    cv_scores = np.empty(5)
    for idx, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_tr, X_te = X[train_idx], X[test_idx]
        y_tr, y_te = y[train_idx], y[test_idx]

        model = CLF(**params)
        model.fit(
            X_tr,
            y_tr,
            eval_set=[(X_te, y_te)],
            eval_metric="auc",
            callbacks=[
                lgbm.early_stopping(100),
                optuna.integration.LightGBMPruningCallback(trial, "auc")
            ]
        )
        preds = model.predict_proba(X_te)[:, 1]
        cv_scores[idx] = roc_auc_score(y_te, preds)
    return np.mean(cv_scores)

study = optuna.create_study(direction='maximize')
study.optimize(partial(objective, X=X_train, y=y_train), n_trials=CFG.optuna_trials, show_progress_bar=True, n_jobs=CFG.n_jobs)
# Out:
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1435 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1436 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1437 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1438 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1439 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1440 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1441 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1442 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1443 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1444 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1445 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1446 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1447 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1448 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1449 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1450 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1451 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1452 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1453 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1454 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1455 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1456 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1457 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1458 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1459 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1460 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1461 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1462 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1463 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1464 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1465 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1466 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1467 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1468 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1469 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1470 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1471 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1472 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1473 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1474 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1475 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1476 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1477 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1478 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1479 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1480 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1481 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1482 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1483 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1484 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1485 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1486 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1487 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1488 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1489 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1490 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1491 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1492 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1493 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1494 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1495 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1496 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1497 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1498 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1499 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1500 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1501 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1502 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1503 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1504 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1505 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1506 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1507 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1508 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1509 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1510 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1511 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1512 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1513 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1514 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1515 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1516 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1517 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1518 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1519 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1520 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1521 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1522 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1523 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1524 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1525 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1526 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1527 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1528 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1529 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1530 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1531 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1532 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1533 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1534 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1535 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1536 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1537 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1538 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1539 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1540 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1541 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1542 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1543 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1544 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1545 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1546 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1547 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1548 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1549 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1550 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1551 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1552 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1553 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1554 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1555 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1556 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1557 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1558 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1559 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1560 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1561 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1562 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1563 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1564 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1565 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1566 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1567 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1568 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1569 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1570 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1571 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1572 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1573 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1574 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1575 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1576 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1577 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1578 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1579 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1580 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1581 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1582 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1583 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1584 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1585 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1586 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1587 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1588 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1589 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1590 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1591 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1592 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1593 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1594 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1595 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1596 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1597 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1598 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1599 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1600 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1601 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1602 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1603 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1604 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1605 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1606 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1607 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1608 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1609 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1610 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1611 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1612 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1613 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1614 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1615 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1616 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1617 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1618 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1619 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1620 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1621 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1622 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1623 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1624 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1625 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1626 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1627 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1628 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1629 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1630 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1631 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1632 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1633 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1634 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1635 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1636 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1637 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1638 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1639 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1640 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1641 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1642 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1643 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1644 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1645 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1646 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1647 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1648 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1649 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1650 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1651 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1652 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1653 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1654 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1655 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1656 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1657 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1658 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1659 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1660 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1661 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 1662 is already reported.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8136 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8137 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8138 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8139 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8140 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8141 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8142 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8143 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8144 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8145 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8146 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8147 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8148 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8149 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8150 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8151 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8152 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8153 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8154 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8155 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8156 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8157 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8158 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8159 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8160 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8161 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8162 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8163 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8164 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8165 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8166 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8167 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8168 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8169 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8170 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8171 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8172 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8173 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8174 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8175 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8176 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8177 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8178 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8179 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8180 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8181 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8182 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8183 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8184 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8185 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8186 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8187 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8188 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8189 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8190 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8191 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8192 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8193 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8194 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8195 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8196 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8197 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8198 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8199 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8200 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8201 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8202 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8203 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8204 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8205 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8206 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8207 is already reported.
#   warnings.warn(
# /home/strawhatdragon100/miniconda3/envs/kaggle/lib/python3.11/site-packages/optuna/trial/_trial.py:494: UserWarning: The reported value is ignored because this `step` 8208 is already reported.
#   warnings.warn(
# Early stopping, best iteration is:
# [8109]	valid_0's auc: 0.856284	valid_0's binary_logloss: 0.456585
# [I 2023-11-09 19:12:14,318] Trial 2 finished with value: 0.8599538830015405 and parameters: {'learning_rate': 0.026557121954838586, 'num_leaves': 280, 'max_depth': 7, 'min_data_in_leaf': 6000, 'max_bin': 209, 'lambda_l1': 100, 'lambda_l2': 90, 'min_gain_to_split': 0.7685838995507621, 'bagging_fraction': 0.7, 'feature_fraction': 0.6000000000000001}. Best is trial 9 with value: 0.8633359382973204.

# %%
params = {**default_params, **study.best_params}
print(params)
# Out:
# {'n_estimators': 10000, 'random_state': 42, 'n_jobs': 8, 'objective': 'binary', 'verbose': -1, 'boosting_type': 'gbdt', 'bagging_freq': 1, 'learning_rate': 0.031115894639831713, 'num_leaves': 1000, 'max_depth': 9, 'min_data_in_leaf': 2900, 'max_bin': 256, 'lambda_l1': 0, 'lambda_l2': 0, 'min_gain_to_split': 2.1168688361634964, 'bagging_fraction': 0.6000000000000001, 'feature_fraction': 0.9}

# %%
pipeline = CLF(**params)
# pipeline.named_steps['classifier'].set_params(**cb_params)
pipeline.fit(X_train, y_train)
# Out:
# LGBMClassifier(bagging_fraction=0.6000000000000001, bagging_freq=1,
#                feature_fraction=0.9, lambda_l1=0, lambda_l2=0,
#                learning_rate=0.031115894639831713, max_bin=256, max_depth=9,
#                min_data_in_leaf=2900, min_gain_to_split=2.1168688361634964,
#                n_estimators=10000, n_jobs=8, num_leaves=1000,
#                objective='binary', random_state=42, verbose=-1)

# %%
predictions = pipeline.predict_proba(X_test)[:, 1]
sample_submission = pd.read_csv(CFG.submission_path, index_col=CFG.index_col)
sample_submission[CFG.target_col] = predictions
sample_submission.to_csv('submission.csv')

# %%
# !kaggle competitions submit -c {CFG.CONTEST_TAG} -f submission.csv -m "LGBM gdbt v3"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/strawhatdragon100/.kaggle/kaggle.json'
# 100%|██████████████████████████████████████| 2.69M/2.69M [00:01<00:00, 2.23MB/s]
# Successfully submitted to Binary Prediction of Smoker Status using Bio-Signals
